# %%
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage as spi
    
# %matplotlib inline

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 10))

#Import  Read H5 file
f = h5.File("051319_scan2d_Hillary_NVsearch_scan5_focus=52.2um_zrel=1.5_um.hdf5", "r")
x, y, image = f['x'], f['y'], f['countrate']
ax1.imshow(image)

#Now let us start to use some filters to pronounce edges
square =  square - ndimage.gaussian_laplace(square, sigma=3)
ax2.imshow(square)

# %%
print(counts.shape)
# Out:
# (1001, 1001)

# %%
# Out:
# countrate
# instrument_settings
# x
# y
