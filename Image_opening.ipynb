# %%
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage as spi
import scipy.ndimage as ndimage
    
# %matplotlib inline

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 10))

#Import  Read H5 file
f = h5.File("051319_scan2d_Hillary_NVsearch_scan5_focus=52.2um_zrel=1.5_um.hdf5", "r")
x, y, image = f['x'], f['y'], f['countrate']
ax1.imshow(image)

#Now let us start to use some filters to pronounce edges
image =  image - ndimage.gaussian_laplace(image, sigma=3)
ax2.imshow(image)

# %%
print(counts.shape)
# Out:
# (1001, 1001)

# %%
# Out:
# countrate
# instrument_settings
# x
# y
